# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_pagos = pd.read_parquet("C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Dataframes/Geral 01-10-2022_30-04-2024/pagos_sdfzs.parquet")

# %%
df_pagos
# Out:
#        Registro        Data                      Paciente  \
# 1      00141365  09/12/2022   MARLENE MAGALHAES BRILHANTE
# 3      00143646  23/05/2023            LUCIA CARAZZA RIOS
# 4      00143646  23/05/2023            LUCIA CARAZZA RIOS
# 5      00143646  23/05/2023            LUCIA CARAZZA RIOS
# 7      00820073  15/03/2024            LUCIA CARAZZA RIOS
# ...         ...         ...                           ...
# 70305  00819410  11/03/2024     JOAO VICTOR BRAGA MARTINS
# 70307  00819456  11/03/2024  ESTHER CASSIA VITORIA DOS SA
# 70309  00821582  25/03/2024          WALTER DO SACRAMENTO
# 70311  00821670  25/03/2024     EDGAR ANTONIO DE CARVALHO
# 70313  00816913  23/02/2024    BRUNO HENRIQUE DE OLIVEIRA
#
#                   Procedimento    Motivo da Glosa        Pago V. Faturado  \
# 1          TC - PELVE OU BACIA  000000 NAO INFORM  12/04/2023        0,00
# 3      HALLUX VALGUS (UM PE) -  000000 NAO INFORM  02/08/2023      256,00
# 4      OSTEOTOMIA OU PSEUDARTR  000000 NAO INFORM  02/08/2023      377,92
# 5      PE PLANO/PE CAVO/COALIS  000000 NAO INFORM  02/08/2023      559,98
# 7      ANESTESIA PARA EXAMES E  000000 NAO INFORM  02/08/2023       88,00
# ...                        ...                ...         ...         ...
# 70305        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70307        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70309        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70311        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70313        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
#
#       V. Recebido Diferenca                               Medico  \
# 1            0,00      0,00                        NAO INFORMADO
# 3          256,00      0,00          MARCIO JOSE PECANHA VALERIO
# 4          377,92      0,00          MARCIO JOSE PECANHA VALERIO
# 5          559,98      0,00          MARCIO JOSE PECANHA VALERIO
# 7            0,00    -88,00          MARCIO JOSE PECANHA VALERIO
# ...           ...       ...                                  ...
# 70305        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70307        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70309        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70311        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70313        0,00    -51,46         ELIZABETH APARECIDA DE AVILA
#
#               Convenio
# 1      Banco do Brasil
# 3      Banco do Brasil
# 4      Banco do Brasil
# 5      Banco do Brasil
# 7      Banco do Brasil
# ...                ...
# 70305          Plamedh
# 70307          Plamedh
# 70309          Plamedh
# 70311          Plamedh
# 70313          Plamedh
#
# [38719 rows x 11 columns]

# %%
df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#       1 df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
#       2 output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
# ----> 3 convenios_por_mes = df.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
#       4 n_convenios = len(convenios_por_mes.columns)
#       5 nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
#
# NameError: name 'df' is not defined

# %%
df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#       9 for i, convenio in enumerate(convenios_por_mes.columns):
#      10     ax = axs[i]
# ---> 11     ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
#      12     ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
#      13     ax.set_xlabel('Mês')
#
# NameError: name 'cmap' is not defined

# %%
from matplotlib.cm import get_cmap

# %%
df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#       9 for i, convenio in enumerate(convenios_por_mes.columns):
#      10     ax = axs[i]
# ---> 11     ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
#      12     ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
#      13     ax.set_xlabel('Mês')
#
# NameError: name 'cmap' is not defined

# %%
df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#       9 for i, convenio in enumerate(convenios_por_mes.columns):
#      10     ax = axs[i]
# ---> 11     ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
#      12     ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
#      13     ax.set_xlabel('Mês')
#
# NameError: name 'cmap' is not defined

# %%
from matplotlib.cm import get_cmap

df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#      11 for i, convenio in enumerate(convenios_por_mes.columns):
#      12     ax = axs[i]
# ---> 13     ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
#      14     ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
#      15     ax.set_xlabel('Mês')
#
# NameError: name 'cmap' is not defined

# %%
cmap = get_cmap('viridis')

df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# <ipython-input-10-2012801229e4>:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('viridis')
# Locator attempting to generate 1641 ticks ([-27850.0, ..., 22066.0]), which exceeds Locator.MAXTICKS (1000).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#      25     ax.set_visible(False)
#      26
# ---> 27 plt.tight_layout()
#      28 plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
#      29 plt.close(fig)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    2585     rect: tuple[float, float, float, float] | None = None,
#    2586 ) -> None:
# -> 2587     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2588
#    2589
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3538             previous_engine = self.get_layout_engine()
#    3539             self.set_layout_engine(engine)
# -> 3540             engine.execute(self)
#    3541             if previous_engine is not None and not isinstance(
#    3542                 previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\layout_engine.py in execute(self, fig)
#     181         renderer = fig._get_renderer()
#     182         with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183             kwargs = get_tight_layout_figure(
#     184                 fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185                 pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\_tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     264             slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
#     265
# --> 266     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                       shape=(max_nrows, max_ncols),
#     268                                       span_pairs=span_pairs,
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\_tight_layout.py in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80         for ax in subplots:
#      81             if ax.get_visible():
# ---> 82                 bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      83
#      84         tight_bbox_raw = Bbox.union(bb)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409     """
#    1410     try:
# -> 1411         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1412     except TypeError:
#    1413         return obj.get_tightbbox(*args, **kwargs)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     452                 "parameter will become keyword-only %(removal)s.",
#     453                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454         return func(*args, **kwargs)
#     455
#     456     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4393         for axis in self._axis_map.values():
#    4394             if self.axison and axis.get_visible():
# -> 4395                 ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4396                 if ba:
#    4397                     bb.append(ba)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409     """
#    1410     try:
# -> 1411         return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1412     except TypeError:
#    1413         return obj.get_tightbbox(*args, **kwargs)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1332         if renderer is None:
#    1333             renderer = self.figure._get_renderer()
# -> 1334         ticks_to_draw = self._update_ticks()
#    1335
#    1336         self._update_label_position(renderer)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1274         """
#    1275         major_locs = self.get_majorticklocs()
# -> 1276         major_labels = self.major.formatter.format_ticks(major_locs)
#    1277         major_ticks = self.get_major_ticks(len(major_locs))
#    1278         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#     647
#     648     def __call__(self, x, pos=0):
# --> 649         result = num2date(x, self.tz).strftime(self.fmt)
#     650         return _wrap_in_tex(result) if self._usetex else result
#     651
#
# ValueError: format %y requires year >= 1900 on Windows
# Locator attempting to generate 1641 ticks ([-27850.0, ..., 22066.0]), which exceeds Locator.MAXTICKS (1000).
# Error in callback <function _draw_all_if_interactive at 0x0000027F41997C10> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\pyplot.py in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#     198
#     199
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1891         if not self._is_idle_drawing:
#    1892             with self._idle_draw_cntx():
# -> 1893                 self.draw(*args, **kwargs)
#    1894
#    1895     @property
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387               else nullcontext()):
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    3152
#    3153                 self.patch.draw(renderer)
# -> 3154                 mimage._draw_list_compositing_images(
#    3155                     renderer, self, artists, self.suppressComposite)
#    3156
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3032                 artists.remove(spine)
#    3033
# -> 3034         self._update_title_position(renderer)
#    3035
#    3036         if not self.axison:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2967                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2968                         or ax.xaxis.get_label_position() == 'top'):
# -> 2969                     bb = ax.xaxis.get_tightbbox(renderer)
#    2970                 if bb is None:
#    2971                     if 'outline' in ax.spines:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1332         if renderer is None:
#    1333             renderer = self.figure._get_renderer()
# -> 1334         ticks_to_draw = self._update_ticks()
#    1335
#    1336         self._update_label_position(renderer)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1274         """
#    1275         major_locs = self.get_majorticklocs()
# -> 1276         major_labels = self.major.formatter.format_ticks(major_locs)
#    1277         major_ticks = self.get_major_ticks(len(major_locs))
#    1278         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#     647
#     648     def __call__(self, x, pos=0):
# --> 649         result = num2date(x, self.tz).strftime(self.fmt)
#     650         return _wrap_in_tex(result) if self._usetex else result
#     651
#
# ValueError: format %y requires year >= 1900 on Windows
# Locator attempting to generate 1641 ticks ([-27850.0, ..., 22066.0]), which exceeds Locator.MAXTICKS (1000).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ACER\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\Users\ACER\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156                 # so that we can inject the orientation
#    2157                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158                     self.figure.draw(renderer)
#    2159             if bbox_inches:
#    2160                 if bbox_inches == "tight":
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    3152
#    3153                 self.patch.draw(renderer)
# -> 3154                 mimage._draw_list_compositing_images(
#    3155                     renderer, self, artists, self.suppressComposite)
#    3156
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3032                 artists.remove(spine)
#    3033
# -> 3034         self._update_title_position(renderer)
#    3035
#    3036         if not self.axison:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2967                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2968                         or ax.xaxis.get_label_position() == 'top'):
# -> 2969                     bb = ax.xaxis.get_tightbbox(renderer)
#    2970                 if bb is None:
#    2971                     if 'outline' in ax.spines:
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1332         if renderer is None:
#    1333             renderer = self.figure._get_renderer()
# -> 1334         ticks_to_draw = self._update_ticks()
#    1335
#    1336         self._update_label_position(renderer)
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1274         """
#    1275         major_locs = self.get_majorticklocs()
# -> 1276         major_labels = self.major.formatter.format_ticks(major_locs)
#    1277         major_ticks = self.get_major_ticks(len(major_locs))
#    1278         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# c:\Users\ACER\anaconda3\lib\site-packages\matplotlib\dates.py in __call__(self, x, pos)
#     647
#     648     def __call__(self, x, pos=0):
# --> 649         result = num2date(x, self.tz).strftime(self.fmt)
#     650         return _wrap_in_tex(result) if self._usetex else result
#     651
#
# ValueError: format %y requires year >= 1900 on Windows

# %%
df_pagos['Data'].unique()
# Out:
# array(['09/12/2022', '23/05/2023', '15/03/2024', '03/10/2022',
#        '03/04/2023', '08/04/2023', '20/05/2023', '02/06/2023',
#        '14/08/2023', '25/08/2023', '02/12/2023', '18/12/2023',
#        '08/01/2024', '08/04/2024', '25/12/2022', '04/05/2023',
#        '06/02/2024', '04/03/2024', '10/10/2022', '14/10/2022',
#        '17/10/2022', '19/10/2022', '26/10/2022', '31/10/2022',
#        '09/11/2022', '16/11/2022', '30/11/2022', '19/12/2022',
#        '04/01/2023', '09/01/2023', '18/01/2023', '27/02/2023',
#        '22/03/2023', '27/03/2023', '19/04/2023', '03/05/2023',
#        '10/05/2023', '22/05/2023', '24/05/2023', '29/05/2023',
#        '05/07/2023', '26/07/2023', '31/07/2023', '09/08/2023',
#        '06/09/2023', '20/09/2023', '25/09/2023', '27/09/2023',
#        '18/10/2023', '06/11/2023', '13/11/2023', '22/11/2023',
#        '10/01/2024', '24/01/2024', '21/02/2024', '06/03/2024',
#        '20/03/2024', '07/12/2022', '14/12/2022', '21/12/2022',
#        '23/12/2022', '26/12/2022', '28/12/2022', '30/12/2022',
#        '06/01/2023', '11/01/2023', '05/04/2023', '12/04/2023',
#        '14/04/2023', '17/04/2023', '21/04/2023', '24/04/2023',
#        '26/04/2023', '28/04/2023', '22/02/2023', '01/05/2023',
#        '05/05/2023', '08/05/2023', '12/05/2023', '15/05/2023',
#        '17/05/2023', '19/05/2023', '31/05/2023', '06/06/2023',
#        '07/06/2023', '09/06/2023', '12/06/2023', '14/06/2023',
#        '16/06/2023', '21/06/2023', '23/06/2023', '26/06/2023',
#        '28/06/2023', '30/06/2023', '19/06/2023', '01/03/2024',
#        '08/03/2024', '11/03/2024', '13/03/2024', '18/03/2024',
#        '22/03/2024', '26/03/2024', '27/03/2024', '29/03/2024',
#        '30/03/2024', '05/10/2022', '07/10/2022', '12/10/2022',
#        '21/10/2022', '24/10/2022', '28/10/2022', '11/10/2022',
#        '03/11/2022', '05/11/2022', '08/11/2022', '11/11/2022',
#        '14/11/2022', '18/11/2022', '23/11/2022', '25/11/2022',
#        '28/11/2022', '02/12/2022', '01/02/2023', '03/02/2023',
#        '21/01/2024', '18/02/2024', '17/03/2024', '15/10/2023',
#        '25/01/2024', '29/09/2022', '18/10/2022', '09/05/2023',
#        '23/01/2024', '30/01/2024', '27/02/2024', '12/03/2024',
#        '17/11/2022', '27/12/2022', '24/06/2023', '02/11/2023',
#        '17/08/2023', '15/11/2022', '18/12/2022', '21/02/2023',
#        '27/08/2023', '21/12/2023', '03/03/2024', '22/09/2022',
#        '22/12/2022', '29/12/2022', '18/05/2023', '04/01/2024',
#        '18/06/2023', '14/05/2023', '30/07/2023', '21/10/2023',
#        '09/10/2022', '30/10/2022', '01/01/2023', '10/02/2024',
#        '29/01/2023', '06/04/2023', '08/01/2023', '05/03/2023',
#        '02/04/2023', '10/06/2023', '09/07/2023', '10/12/2023',
#        '06/11/2022', '15/08/2023', '24/03/2024', '07/09/2023',
#        '12/02/2023', '01/04/2024', '16/07/2023', '23/10/2022',
#        '03/12/2022', '23/04/2023', '27/01/2024', '23/03/2024',
#        '19/11/2023', '12/03/2023', '28/05/2023', '26/03/2023',
#        '09/04/2023', '17/12/2023', '02/11/2022', '26/02/2023',
#        '17/06/2023', '13/08/2023', '24/09/2023', '05/11/2023',
#        '16/12/2023', '14/01/2024', '04/04/2024', '14/03/2024',
#        '05/04/2024', '09/04/2024', '31/03/2024', '16/04/2024',
#        '10/03/2024', '07/04/2024', '15/04/2024', '10/04/2024',
#        '02/04/2024', '19/09/2022', '18/04/2024', '19/04/2024',
#        '23/04/2024', '17/04/2024', '30/12/1899', '22/04/2024',
#        '06/04/2024', '24/04/2024', '14/09/2022', '24/07/2022'],
#       dtype=object)

# %%
df_pagos = df_pagos[~df_pagos['Paciente'].str.contains('TESTE', na=False)]

# %%
cmap = get_cmap('viridis')

df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory_teste = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos oara Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# <ipython-input-13-2012801229e4>:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('viridis')
# <ipython-input-13-2012801229e4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ACER\Meu Drive\Hospital Nossa Senhora das Mercês\Códigos Python\Códigos Funcionando\Gráficos Gerais.py in <module>
#      26
#      27 plt.tight_layout()
# ---> 28 plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
#      29 plt.close(fig)
#
# NameError: name 'output_directory' is not defined

# %%
cmap = get_cmap('viridis')

df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos para o Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png")
plt.close(fig)
# Out:
# <ipython-input-14-0a1330850d08>:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('viridis')
# <ipython-input-14-0a1330850d08>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time

# %%
cmap = get_cmap('viridis')

df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos para o Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png", dpi=400)
plt.close(fig)
# Out:
# <ipython-input-15-d5298b67543d>:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('viridis')
# <ipython-input-15-d5298b67543d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time

# %%
df_pagos = df_pagos[~df_pagos['Convenio'].str.contains('COMPRA DE LEITO DA SES/MG', na=False)]

# %%
cmap = get_cmap('viridis')

df_pagos['Mês'] = pd.to_datetime(df_pagos['Data'], format='%d/%m/%Y').dt.to_period('M').dt.start_time
output_directory = "C:/Users/ACER/Meu Drive/Hospital Nossa Senhora das Mercês/Códigos Python/Códigos Funcionando/Gráficos Médicos/teste"
convenios_por_mes = df_pagos.groupby(['Mês', 'Convenio']).size().unstack(fill_value=0)
n_convenios = len(convenios_por_mes.columns)
nrows = (n_convenios + 2) // 3  # Assegura que haja linhas suficientes para todos os convênios
fig, axs = plt.subplots(nrows=nrows, ncols=3, figsize=(18, 3 * nrows), sharex=True, squeeze=False)

axs = axs.flatten()  # Achata o array de axes para facilitar a iteração
for i, convenio in enumerate(convenios_por_mes.columns):
    ax = axs[i]
    ax.plot(convenios_por_mes.index, convenios_por_mes[convenio], label=f'{convenio}', marker='o', linestyle='-', color=cmap(i / n_convenios))
    ax.set_title(f'Quantidade de Procedimentos para o Convênio: {convenio}')
    ax.set_xlabel('Mês')
    ax.set_ylabel('Quantidade de Procedimentos')
    ax.legend()
    ax.grid(True)
    # Definir o formato de data para o eixo x
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%m\n%y'))  # Formato: "Abreviação do Mês Ano"

# Oculta os axes extras se houver
for ax in axs[n_convenios:]:
    ax.set_visible(False)

plt.tight_layout()
plt.savefig(f"{output_directory}/numero_procedimentos_por_convenio_por_mes.png", dpi=400)
plt.close(fig)
# Out:
# <ipython-input-17-d5298b67543d>:1: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = get_cmap('viridis')

# %%
df_pagos
# Out:
#        Registro        Data                      Paciente  \
# 1      00141365  09/12/2022   MARLENE MAGALHAES BRILHANTE
# 3      00143646  23/05/2023            LUCIA CARAZZA RIOS
# 4      00143646  23/05/2023            LUCIA CARAZZA RIOS
# 5      00143646  23/05/2023            LUCIA CARAZZA RIOS
# 7      00820073  15/03/2024            LUCIA CARAZZA RIOS
# ...         ...         ...                           ...
# 70305  00819410  11/03/2024     JOAO VICTOR BRAGA MARTINS
# 70307  00819456  11/03/2024  ESTHER CASSIA VITORIA DOS SA
# 70309  00821582  25/03/2024          WALTER DO SACRAMENTO
# 70311  00821670  25/03/2024     EDGAR ANTONIO DE CARVALHO
# 70313  00816913  23/02/2024    BRUNO HENRIQUE DE OLIVEIRA
#
#                   Procedimento    Motivo da Glosa        Pago V. Faturado  \
# 1          TC - PELVE OU BACIA  000000 NAO INFORM  12/04/2023        0,00
# 3      HALLUX VALGUS (UM PE) -  000000 NAO INFORM  02/08/2023      256,00
# 4      OSTEOTOMIA OU PSEUDARTR  000000 NAO INFORM  02/08/2023      377,92
# 5      PE PLANO/PE CAVO/COALIS  000000 NAO INFORM  02/08/2023      559,98
# 7      ANESTESIA PARA EXAMES E  000000 NAO INFORM  02/08/2023       88,00
# ...                        ...                ...         ...         ...
# 70305        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70307        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70309        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70311        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
# 70313        EM PRONTO SOCORRO  000000 NAO INFORM  28/03/2024       51,46
#
#       V. Recebido Diferenca                               Medico  \
# 1            0,00      0,00                        NAO INFORMADO
# 3          256,00      0,00          MARCIO JOSE PECANHA VALERIO
# 4          377,92      0,00          MARCIO JOSE PECANHA VALERIO
# 5          559,98      0,00          MARCIO JOSE PECANHA VALERIO
# 7            0,00    -88,00          MARCIO JOSE PECANHA VALERIO
# ...           ...       ...                                  ...
# 70305        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70307        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70309        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70311        0,00    -51,46  DANIELLE DA CONCEICAO RESENDE ASSIS
# 70313        0,00    -51,46         ELIZABETH APARECIDA DE AVILA
#
#               Convenio        Mês
# 1      Banco do Brasil 2022-12-01
# 3      Banco do Brasil 2023-05-01
# 4      Banco do Brasil 2023-05-01
# 5      Banco do Brasil 2023-05-01
# 7      Banco do Brasil 2024-03-01
# ...                ...        ...
# 70305          Plamedh 2024-03-01
# 70307          Plamedh 2024-03-01
# 70309          Plamedh 2024-03-01
# 70311          Plamedh 2024-03-01
# 70313          Plamedh 2024-02-01
#
# [38690 rows x 12 columns]
